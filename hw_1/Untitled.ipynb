# %%
import pandas as pd
import numpy as np

data = pd.read_csv('smart_card_data.csv')
data
# Out:
#              Time_In      Time_Out       Card_Id  Fare  StationId_In  \
# 0       4/1/14 13:14  4/1/14 13:19  970900000000   190            10
# 1       4/1/14 14:46  4/1/14 14:52  970900000000   190             9
# 2        4/1/14 9:48  4/1/14 10:25  970900000000   380            37
# 3       4/1/14 11:08  4/1/14 11:46  970900000000   380             9
# 4       4/1/14 17:43  4/1/14 18:00  995572000000   190            11
# 5       4/1/14 17:01  4/1/14 17:04  972672000000   190            26
# 6       4/1/14 13:29  4/1/14 14:07  972672000000   380            30
# 7       4/1/14 14:35  4/1/14 15:12  972672000000   380            44
# 8       4/1/14 18:31  4/1/14 18:44  972672000000   190            31
# 9       4/1/14 20:32  4/1/14 20:51  972672000000   190            34
# 10      4/1/14 14:00  4/1/14 14:24  972672000000   285            30
# 11      4/1/14 21:17  4/1/14 21:49  972672000000   285            22
# 12      4/1/14 17:58  4/1/14 18:10  972672000000   190            30
# ...

# %%
data = data.sort_values(by=['Card_Id'])
a=list(data['Card_Id'].value_counts())

# %%
a[:-100]
# Out:
# [64023,
#  54402,
#  44533,
#  28123,
#  26455,
#  24384,
#  23118,
#  22604,
#  21325,
#  20167,
#  17755,
#  17098,
#  15340,
#  14994,
#  13706,
#  13056,
#  12461,
#  11766,
#  11433,
#  11218,
#  10941,
#  10569,
#  10411,
#  10405,
#  10244,
#  9656,
#  9613,
#  9323,
#  9264,
#  8908,
#  8817,
#  8665,
#  8648,
#  8399,
#  8231,
#  8206,
#  8193,
#  7882,
#  7726,
#  7321,
#  7209,
#  7026,
#  6955,
#  6931,
#  6752,
#  6439,
#  6179,
#  5912,
#  5904]
